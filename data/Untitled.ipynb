# %%
with open("nasty_data.txt", "r", encoding="utf-8") as file:
    text = file.read()

# %%
all_question = []

# %%
for full in text.split("\n\n"):
    question, answer =  full.split("\n➡️") if "\n➡️" in full else full.split("\n👉")
    
    all_question.append([question, answer])

# %%
all_question
# Out:
# [['1. К какой группе веществ относятся полупроводники?',
#   ' К веществам, занимающим промежуточное положение между проводниками и диэлектриками.'],
#  ['2. При каких условиях возрастает электрическая проводимость полупроводников?',
#   ' При повышении температуры, освещении или при добавлении примесей (легировании).'],
#  ['3. Что из перечисленного является простым полупроводником?',
#   ' Кремний (Si) или германий (Ge).'],
#  ['4. Какие носители заряда, кроме движения электронов, существуют в полупроводнике?',
#   ' Дырки (положительные носители заряда).'],
#  ['5. Как называются два вида проводимости в полупроводниках?',
#   ' Электронная и дырочная проводимость.'],
#  ['6. Как возникает проводимость в чистых (интринзикных) полупроводниках?',
#   ' При нагревании электроны переходят из валентной зоны в зону проводимости, оставляя после себя дырки.'],
#  ['7. Что делают для увеличения проводимости полупроводников?',
#   ' Вводят примеси (легируют).'],
# ...

# %%
len(all_question)
# Out:
# 100
